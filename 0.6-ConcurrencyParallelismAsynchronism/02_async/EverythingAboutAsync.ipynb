# %% [markdown]
# ⚙️ MÓDULO 2 — Como o async funciona POR DENTRO
#
# Aqui você começa a virar expert.
#
# Conceitos fundamentais:
#
# Event loop
#
# Task queue
#
# Cooperative multitasking
#
# Context switch lógico
#
# Você deve entender:
#
# ✔ O que é o event loop
# ✔ Quem decide quando uma coroutine roda
# ✔ Por que await é um ponto de troca
#
# 📌 Isso é o coração do async

# %% [markdown]
# 🐍 MÓDULO 3 — Sintaxe básica do async em Python
#
# Só agora entramos em código.
#
# Conteúdo:
#
# async def
#
# await
#
# coroutines
#
# asyncio.run()
#
# Você deve saber:
#
# ✔ Criar e executar coroutines
# ✔ Entender por que async def não executa sozinho
# ✔ Ler traceback async

# %% [markdown]
# 🔄 MÓDULO 4 — Tasks e Futures
#
# Aqui o async fica poderoso.
#
# Conteúdo:
#
# asyncio.create_task
#
# Task
#
# Future
#
# Ciclo de vida de uma task
#
# Você deve dominar:
#
# ✔ Diferença entre coroutine e task
# ✔ Cancelamento de tasks
# ✔ States de uma task

# %% [markdown]
# ⏱️ MÓDULO 5 — Concorrência real com asyncio
#
# Async não é sequencial.
#
# Ferramentas:
#
# asyncio.gather
#
# asyncio.wait
#
# as_completed
#
# Você deve:
#
# ✔ Executar milhares de I/Os concorrentes
# ✔ Controlar falhas individuais
# ✔ Evitar vazamento de tasks

# %% [markdown]
# 🚦 MÓDULO 6 — Sincronização no mundo async
#
# Sim, async também precisa disso.
#
# Primitivas:
#
# asyncio.Lock
#
# asyncio.Semaphore
#
# asyncio.Event
#
# asyncio.Condition
#
# ✔ Saber quando sincronizar
# ✔ Evitar deadlocks lógicos
# ✔ Limitar concorrência corretamente

# %% [markdown]
# 🌐 MÓDULO 7 — Async I/O na prática
#
# Onde async brilha.
#
# Casos reais:
#
# HTTP (aiohttp, httpx)
#
# Banco de dados async
#
# Filesystem async
#
# APIs externas
#
# ✔ Escrever clientes HTTP eficientes
# ✔ Controlar timeouts
# ✔ Implementar retries

# %% [markdown]
# 🧬 MÓDULO 9 — Backpressure e controle de carga
#
# Poucos dominam isso.
#
# Conceitos:
#
# Producer / Consumer
#
# Filas assíncronas
#
# Rate limiting
#
# Ferramentas:
#
# asyncio.Queue
#
# Semaphores como throttle
#
# ✔ Evitar overload
# ✔ Controlar memória
# ✔ Sistemas resilientes

# %% [markdown]
# 🧪 MÓDULO 12 — Testes em código assíncrono
#
# Tema negligenciado.
#
# Ferramentas:
#
# pytest-asyncio
#
# Mocks async
#
# Testes de concorrência
#
# ✔ Testar corretamente
# ✔ Evitar flaky tests
# ✔ Testes determinísticos
