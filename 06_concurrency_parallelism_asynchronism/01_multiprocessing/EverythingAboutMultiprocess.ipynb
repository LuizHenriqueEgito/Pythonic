# %% [markdown]
# O que é memória virutal
#
# O que é CPI core vs CPU logica
# Você deve sair sabendo:
#
# ✔ Explicar por que multiprocessing existe
# ✔ Quando NÃO usar multiprocessing
# ✔ Entender por que o GIL não afeta processos

# %% [markdown]
# 🧠 MÓDULO 1 — O problema que o multiprocessing resolve
#
# Antes da solução, entenda a dor.
#
# Conceitos-chave:
#
# GIL (Global Interpreter Lock)
#
# CPU-bound vs I/O-bound
#
# Por que threading não escala CPU-bound
#
# Você deve saber:
#
# ✔ Identificar código CPU-bound
# ✔ Explicar por que multiprocessing escala
# ✔ Comparar tempo real entre:
#
# código single-thread
#
# threading
#
# multiprocessing

# %% [markdown]
# ⚙️ MÓDULO 2 — Processos no sistema operacional
#
# Aqui você vira adulto.
#
# Conceitos:
#
# Fork vs Spawn vs Forkserver
#
# Process ID (PID)
#
# Espaço de memória isolado
#
# Copy-on-write (COW)
#
# Você deve saber:
#
# ✔ O que acontece quando um processo nasce
# ✔ Diferença entre Linux, macOS e Windows
# ✔ Por que if __name__ == "__main__" é obrigatório

# %% [markdown]
# 🐍 MÓDULO 3 — multiprocessing básico em Python
#
# Primeiro contato real.
#
# Conteúdo:
#
# multiprocessing.Process
#
# .start(), .join()
#
# Comunicação mínima
#
# Habilidades:
#
# ✔ Criar processos
# ✔ Sincronizar execução
# ✔ Evitar processos zumbis
#
# 📌 Exercício típico: calcular primos em paralelo

# %% [markdown]
# 📦 MÓDULO 4 — Passagem de dados entre processos
#
# Aqui começam os erros comuns.
#
# Ferramentas:
#
# Queue
#
# Pipe
#
# Value e Array
#
# Você precisa dominar:
#
# ✔ Pickle (serialização)
# ✔ O custo de copiar dados
# ✔ Deadlocks básicos

# %% [markdown]
# 🔒 MÓDULO 5 — Sincronização entre processos
#
# Onde bugs aparecem se você não entender bem.
#
# Conceitos:
#
# Race conditions
#
# Critical section
#
# Locks vs Semaphores
#
# Ferramentas:
#
# Lock
#
# RLock
#
# Semaphore
#
# Condition
#
# Event
#
# Você deve:
#
# ✔ Prevenir corrupção de dados
# ✔ Entender starvation e deadlock
# ✔ Saber quando NÃO sincronizar

# %% [markdown]
# 🧠 MÓDULO 6 — Pools de processos (nível profissional)
#
# 90% do código real usa isso.
#
# Conteúdo:
#
# multiprocessing.Pool
#
# map, imap, starmap
#
# apply_async
#
# Habilidades:
#
# ✔ Balancear carga
# ✔ Controlar paralelismo
# ✔ Coletar resultados corretamente
#
# 📌 Comparar:
#
# Pool vs Process manual

# %% [markdown]
# 🚀 MÓDULO 7 — concurrent.futures.ProcessPoolExecutor
#
# API moderna e limpa.
#
# Conteúdo:
#
# ProcessPoolExecutor
#
# submit
#
# as_completed
#
# Futures
#
# Você deve:
#
# ✔ Escrever código mais legível
# ✔ Tratar exceções corretamente
# ✔ Cancelar tarefas

# %% [markdown]
# 📊 MÓDULO 8 — Performance real e tuning
#
# Aqui você vira expert de verdade.
#
# Conceitos:
#
# Overhead de criação de processos
#
# Granularidade das tarefas
#
# Amdahl’s Law
#
# Cache locality
#
# Ferramentas:
#
# time
#
# timeit
#
# perf
#
# cProfile
#
# ✔ Saber quando multiprocessing piora performance

# %% [markdown]
# 🧬 MÓDULO 9 — Memória compartilhada moderna
#
# Pouca gente domina isso.
#
# Conteúdo:
#
# multiprocessing.shared_memory
#
# NumPy + shared memory
#
# Evitar cópias gigantes
#
# Você deve:
#
# ✔ Compartilhar grandes arrays
# ✔ Entender alinhamento e segurança
# ✔ Saber quando usar vs evitar
